# %%
from __future__ import print_function
import sys
import os
from matplotlib import pyplot as plt

from local_config import CURRENT_DIR
sys.path.append(os.path.join(CURRENT_DIR, ".."))
try:
    from config import Config
except:
    print("cannot load modules")
    sys.exit(0)

# %%
from data_loader import CamvidDataset
dt_config = Config()
dataset = CamvidDataset(data_path=dt_config.DATA_PATH)

# %%
dt_config.display()
# Out:
# Configurations:
# CURRENT_DIR                    /home/buggy/publicWorkspace/dev/enet_pytorch
# DATA_PATH                      /home/buggy/publicWorkspace/dev/enet_pytorch/data

# %%
plt.figure(figsize=(15,15))
plt.imshow(dataset.legend)

# %%
sample_overlay_img = dataset.get_overlay_image(10)

plt.figure(figsize=(15,15))
plt.imshow(sample_overlay_img)

# %%
dataset_distribution = dataset.class_distribution()

# %%
import pandas as pd

dataset_distribution_pd = pd.Series(dataset_distribution)
dataset_distribution_pd
# Out:
# Animal                      0
# Archway                 21484
# Bicyclist             1546828
# Bridge                      0
# Building             17143805
# Car                   1014145
# CartLuggagePram          9595
# Child                   61545
# Column_Pole            393607
# Fence                 2153179
# LaneMkgsDriv          1197756
# LaneMkgsNonDriv             1
# Misc_Text              163228
# MotorcycleScooter           0
# OtherMoving            500317
# ParkingBlock                0
# Pedestrian             454587
# Road                 18965140
# RoadShoulder                0
# Sidewalk              6084579
# SignSymbol              50346
# Sky                   6425625
# SUVPickupTruck              0
# TrafficCone                 0
# TrafficLight           408917
# Train                       0
# Tree                 11354330
# Truck_Bus              206989
# Tunnel                      0
# VegetationMisc          77471
# Void                   602756
# Wall                   974970
# dtype: int64

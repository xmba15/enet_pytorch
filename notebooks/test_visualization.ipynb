# %%
from __future__ import print_function
import sys
import os
import cv2
from matplotlib import pyplot as plt

from local_config import CURRENT_DIR
sys.path.append(os.path.join(CURRENT_DIR, ".."))
try:
    from config import Config
except:
    print("cannot load modules")
    sys.exit(0)

# %%
from data_loader import CamvidDataset
dt_config = Config()
dataset = CamvidDataset(data_path=dt_config.DATA_PATH, phase="train")

# %%
dt_config.display()
# Out:
# Configurations:
# BATCH_SIZE                     20
# CURRENT_DIR                    /home/btran/publicWorkspace/dev/enet_pytorch
# DATA_PATH                      /home/btran/publicWorkspace/dev/enet_pytorch/data
# IMG_SIZE                       (360, 480)
# NUM_EPOCHS                     50
# SAVED_MODEL_PATH               /home/btran/publicWorkspace/dev/enet_pytorch/saved_models

# %%
plt.figure(figsize=(15,15))
plt.imshow(cv2.cvtColor(dataset.legend, cv2.COLOR_BGR2RGB))

# %%
sample_overlay_img = dataset.get_overlay_image(10)

plt.figure(figsize=(15,15))
plt.imshow(cv2.cvtColor(sample_overlay_img, cv2.COLOR_BGR2RGB))

# %%
dataset_distribution = dataset.class_distribution()

# %%
import pandas as pd

dataset_distribution_pd = pd.Series(dataset_distribution)
dataset_distribution_pd
# Out:
# Void          10682767
# Bicyclist     14750079
# Building        623349
# Car           20076880
# Fence          2845085
# Pavement       6166762
# Pedestrian      743859
# Pole            714595
# Road           3719877
# SignSymbol      405385
# Sky             184967
# Tree           2503995
# dtype: int64

# %%
len(dataset)
# Out:
# 367

# %%
weights = dataset.weighted_class()

print(dataset.classes)
weights
# Out:
# ['Void', 'Bicyclist', 'Building', 'Car', 'Fence', 'Pavement', 'Pedestrian', 'Pole', 'Road', 'SignSymbol', 'Sky', 'Tree']
# array([ 5.79203481,  4.44028773, 34.02166463,  3.44690044, 15.91194352,
#         9.02023585, 32.01377376, 32.47892445, 13.20714089, 38.38765298,
#        44.13450551, 17.30636391])
